# %%
# Import libraries
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# Import data
data = pd.read_csv("../car_evaluation.csv")
n_data = pd.read_csv("numeric.csv")
data.head()
# Out:
#    vhigh vhigh.1  2 2.1  small   low  unacc
# 0  vhigh   vhigh  2   2  small   med  unacc
# 1  vhigh   vhigh  2   2  small  high  unacc
# 2  vhigh   vhigh  2   2    med   low  unacc
# 3  vhigh   vhigh  2   2    med   med  unacc
# 4  vhigh   vhigh  2   2    med  high  unacc

# %%
# Check types and shape
print (data.shape)
print (data.dtypes)
# Out:
# (1727, 7)
# vhigh      object
# vhigh.1    object
# 2          object
# 2.1        object
# small      object
# low        object
# unacc      object
# dtype: object

# %%
print (n_data.shape)
print (n_data.dtypes)
# Out:
# (1727, 7)
# vhigh      int64
# vhigh.1    int64
# 2          int64
# 2.1        int64
# small      int64
# low        int64
# unacc      int64
# dtype: object

# %%
# Check missing values
print (data.isnull().sum())
# Out:
# vhigh      0
# vhigh.1    0
# 2          0
# 2.1        0
# small      0
# low        0
# unacc      0
# dtype: int64

# %%
print (n_data.isnull().sum())
# Out:
# vhigh      0
# vhigh.1    0
# 2          0
# 2.1        0
# small      0
# low        0
# unacc      0
# dtype: int64

# %% [markdown]
# There's no any missing value

# %%
# Check each column
for col in data.columns:
    print (f"{col:8}: {data[col].unique()}")
# Out:
# vhigh   : ['vhigh' 'high' 'med' 'low']
# vhigh.1 : ['vhigh' 'high' 'med' 'low']
# 2       : ['2' '3' '4' '5more']
# 2.1     : ['2' '4' 'more']
# small   : ['small' 'med' 'big']
# low     : ['med' 'high' 'low']
# unacc   : ['unacc' 'acc' 'vgood' 'good']

# %%
for col in n_data.columns:
    print (f"{col:8}: {n_data[col].unique()}")
# Out:
# vhigh   : [4 3 2 1]
# vhigh.1 : [4 3 2 1]
# 2       : [4 3 2 1]
# 2.1     : [3 2 1]
# small   : [3 2 1]
# low     : [3 2 1]
# unacc   : [4 3 2 1]

# %%
# Describe
data.describe()
# Out:
#        vhigh vhigh.1     2   2.1 small   low  unacc
# count   1727    1727  1727  1727  1727  1727   1727
# unique     4       4     4     3     3     3      4
# top     high    high     3     4   med   med  unacc
# freq     432     432   432   576   576   576   1209

# %%
n_data.describe()
# Out:
#              vhigh      vhigh.1            2          2.1        small  \
# count  1727.000000  1727.000000  1727.000000  1727.000000  1727.000000
# mean      2.499131     2.499131     2.499131     1.999421     1.999421
# std       1.118098     1.118098     1.118098     0.816615     0.816615
# min       1.000000     1.000000     1.000000     1.000000     1.000000
# 25%       1.500000     1.500000     1.500000     1.000000     1.000000
# 50%       2.000000     2.000000     2.000000     2.000000     2.000000
# 75%       3.000000     3.000000     3.000000     3.000000     3.000000
# max       4.000000     4.000000     4.000000     3.000000     3.000000
#
#                low        unacc
# count  1727.000000  1727.000000
# mean      2.000579     3.582513
# std       0.816615     0.747337
# min       1.000000     1.000000
# 25%       1.000000     3.000000
# 50%       2.000000     4.000000
# 75%       3.000000     4.000000
# max       3.000000     4.000000

# %%
# Value counts
for col in data.columns:
    print (data[col].value_counts())
# Out:
# high     432
# med      432
# low      432
# vhigh    431
# Name: vhigh, dtype: int64
# high     432
# med      432
# low      432
# vhigh    431
# Name: vhigh.1, dtype: int64
# 3        432
# 4        432
# 5more    432
# 2        431
# Name: 2, dtype: int64
# 4       576
# more    576
# 2       575
# Name: 2.1, dtype: int64
# med      576
# big      576
# small    575
# Name: small, dtype: int64
# med     576
# high    576
# low     575
# Name: low, dtype: int64
# unacc    1209
# acc       384
# good       69
# vgood      65
# Name: unacc, dtype: int64

# %%
for col in n_data.columns:
    print (n_data[col].value_counts())
# Out:
# 3    432
# 2    432
# 1    432
# 4    431
# Name: vhigh, dtype: int64
# 3    432
# 2    432
# 1    432
# 4    431
# Name: vhigh.1, dtype: int64
# 3    432
# 2    432
# 1    432
# 4    431
# Name: 2, dtype: int64
# 2    576
# 1    576
# 3    575
# Name: 2.1, dtype: int64
# 2    576
# 1    576
# 3    575
# Name: small, dtype: int64
# 3    576
# 2    576
# 1    575
# Name: low, dtype: int64
# 4    1209
# 3     384
# 1      69
# 2      65
# Name: unacc, dtype: int64

# %%
# Correlation
print (n_data.corr())
# Out:
#             vhigh   vhigh.1         2       2.1     small       low     unacc
# vhigh    1.000000 -0.001043 -0.001043 -0.000952 -0.000952  0.000952  0.286273
# vhigh.1 -0.001043  1.000000 -0.001043 -0.000952 -0.000952  0.000952  0.254378
# 2       -0.001043 -0.001043  1.000000 -0.000952 -0.000952  0.000952  0.056075
# 2.1     -0.000952 -0.000952 -0.000952  1.000000 -0.000869  0.000869  0.336622
# small   -0.000952 -0.000952 -0.000952 -0.000869  1.000000  0.000869  0.121120
# low      0.000952  0.000952  0.000952  0.000869  0.000869  1.000000 -0.281560
# unacc    0.286273  0.254378  0.056075  0.336622  0.121120 -0.281560  1.000000

# %%
print (n_data.corr()["unacc"])
# Out:
# vhigh      0.286273
# vhigh.1    0.254378
# 2          0.056075
# 2.1        0.336622
# small      0.121120
# low       -0.281560
# unacc      1.000000
# Name: unacc, dtype: float64

# %%
# Visualize the data
for col in n_data.columns:
    plt.boxplot(n_data[col].values)
    plt.ylabel(col)
    plt.show()

# %% [markdown]
# There aren't a lot of outliers and we can continue despite them

# %%
for col in n_data.columns:
    plt.scatter(n_data[col].values, n_data["unacc"].values)
    plt.xlabel(col)
    plt.show()
