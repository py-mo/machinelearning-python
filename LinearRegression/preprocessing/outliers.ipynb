# %% [markdown]
# ### Import necessary libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ### Import date

# %%
data = pd.read_csv("corr_data.csv")
data.head()
# Out:
#    carlength  carwidth  curbweight  enginesize  horsepower    price  Brand
# 0      168.8      64.1        2548         130         111  13495.0    1.0
# 1      168.8      64.1        2548         130         111  16500.0    1.0
# 2      171.2      65.5        2823         152         154  16500.0    1.0
# 3      176.6      66.2        2337         109         102  13950.0    1.0
# 4      176.6      66.4        2824         136         115  17450.0    1.0

# %%
# Visualize the data
for col in data.columns:
    plt.boxplot(data[col].values)
    plt.xlabel(col)
    plt.show()

# %% [markdown]
# There are a few outliers and we can continue despite them
